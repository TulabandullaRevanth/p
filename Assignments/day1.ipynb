# %%
# Check Python version
import sys
print("Python version:", sys.version)
 
# Check installed modules
help("modules")
 
# Quick version compare
if sys.version_info >= (3, 10):
    print("✅ You’re on a modern Python version!")
else:
    print("⚠️ Consider Upgrading Python.")
# Out:
# Python version: 3.12.7 | packaged by Anaconda, Inc. | (main, Oct  4 2024, 13:17:27) [MSC v.1929 64 bit (AMD64)]
#
# Please wait a moment while I gather a list of all available modules...
# c:\Users\16052\anaconda3\Lib\site-packages\paramiko\pkey.py:82: CryptographyDeprecationWarning: TripleDES has been moved to cryptography.hazmat.decrepit.ciphers.algorithms.TripleDES and will be removed from this module in 48.0.0.
#   "cipher": algorithms.TripleDES,
# c:\Users\16052\anaconda3\Lib\site-packages\paramiko\transport.py:219: CryptographyDeprecationWarning: Blowfish has been moved to cryptography.hazmat.decrepit.ciphers.algorithms.Blowfish and will be removed from this module in 45.0.0.
#   "class": algorithms.Blowfish,
# c:\Users\16052\anaconda3\Lib\site-packages\paramiko\transport.py:243: CryptographyDeprecationWarning: TripleDES has been moved to cryptography.hazmat.decrepit.ciphers.algorithms.TripleDES and will be removed from this module in 48.0.0.
#   "class": algorithms.TripleDES,
# c:\Users\16052\anaconda3\Lib\site-packages\nltk\twitter\__init__.py:20: UserWarning: The twython library has not been installed. Some functionality from the twitter package will not be available.
#   warnings.warn(
# c:\Users\16052\anaconda3\Lib\pkgutil.py:78: UserWarning: The numpy.array_api submodule is still experimental. See NEP 47.
#   __import__(info.name)
# c:\Users\16052\anaconda3\Lib\site-packages\pydantic\experimental\__init__.py:7: PydanticExperimentalWarning:
#
# This module is experimental, its contents are subject to change and deprecation.
#
# No QCoreApplication instance found. Application patches not applied. You have to call load_stylesheet function after instantiation of QApplication to take effect.
# 3204bda914b7f2c6f497__mypyc cloudpickle         markupsafe          slugify
# IPython             cmath               marshal             smart_open
# OpenSSL             cmd                 math                smmap
# PIL                 code                matplotlib          smtplib
# PyQt5               codecs              matplotlib_inline   sndhdr
# __future__          codeop              mccabe              sniffio
# __hello__           collections         mdit_py_plugins     snowballstemmer
# __phello__          colorama            mdurl               socket
# _abc                colorcet            menuinst            socketserver
# _aix_support        colorsys            mimetypes           socks
# _argon2_cffi_bindings comm                mistune             sockshandler
# _ast                commctrl            mkl                 sortedcontainers
# _asyncio            compileall          mkl_fft             soupsieve
# _bisect             concurrent          mkl_random          sphinx
# _black_version      conda               mmap                spyder
# _blake2             conda_build         mmapfile            spyder_kernels
# _brotli             conda_content_trust mmsystem            sqlalchemy
# _bz2                conda_env           modulefinder        sqlite3
# _cffi_backend       conda_index         more_itertools      sre_compile
# _codecs             conda_libmamba_solver mpmath              sre_constants
# _codecs_cn          conda_pack          msgpack             sre_parse
# _codecs_hk          conda_package_handling msilib              ssl
# _codecs_iso2022     conda_package_streaming msvcrt              sspi
# _codecs_jp          conda_token         multidict           sspicon
# _codecs_kr          configparser        multipledispatch    stack_data
# _codecs_tw          constantly          multiprocessing     stat
# _collections        contextlib          mypy                statistics
# _collections_abc    contextvars         mypy_extensions     statsmodels
# _compat_pickle      contourpy           mypyc               streamlit
# _compression        cookiecutter        nacl                string
# _contextvars        copy                navigator_updater   stringprep
# _csv                copyreg             nb_conda_kernels    struct
# _ctypes             cpuinfo             nbclient            subprocess
# _ctypes_test        crypt               nbconvert           sunau
# _datetime           cryptography        nbformat            sympy
# _decimal            cssselect           nest_asyncio        symtable
# _distutils_hack     csv                 netbios             sys
# _elementtree        ctypes              netrc               sysconfig
# _functools          curl                networkx            tables
# _hashlib            curses              nltk                tabnanny
# _heapq              cwp                 nntplib             tabulate
# _imp                cycler              notebook            tarfile
# _io                 cytoolz             notebook_shim       tblib
# _json               dask                nt                  telnetlib
# _locale             dask_expr           ntpath              tempfile
# _lsprof             dataclasses         ntsecuritycon       tenacity
# _lzma               datashader          nturl2path          terminado
# _markupbase         datetime            numba               test
# _md5                dateutil            numbergen           test_pycosat
# _msi                dbi                 numbers             text_unidecode
# _multibytecodec     dbm                 numexpr             textdistance
# _multiprocessing    dde                 numpy               textwrap
# _nsis               debugpy             numpydoc            this
# _opcode             decimal             odbc                threading
# _operator           decorator           opcode              threadpoolctl
# _osx_support        defusedxml          openpyxl            three_merge
# _overlapped         diff_match_patch    operator            tifffile
# _pickle             difflib             optparse            time
# _plotly_future_     dill                os                  timeit
# _plotly_utils       dis                 overrides           timer
# _py_abc             distributed         packaging           tinycss2
# _pydatetime         distro              pandas              tkinter
# _pydecimal          docstring_to_markdown pandocfilters       tldextract
# _pyio               doctest             panel               tlz
# _pylong             docutils            param               token
# _pytest             dotenv              paramiko            tokenize
# _queue              email               parsel              toml
# _random             encodings           parso               tomli
# _ruamel_yaml        ensurepip           partd               tomlkit
# _sha1               enum                pathlib             tomllib
# _sha2               erfa                pathspec            toolz
# _sha3               errno               patsy               tornado
# _signal             et_xmlfile          pdb                 tqdm
# _sitebuiltins       executing           perfmon             trace
# _socket             fastjsonschema      pexpect             traceback
# _sqlite3            faulthandler        pickle              tracemalloc
# _sre                filecmp             pickleshare         traitlets
# _ssl                fileinput           pickletools         truststore
# _stat               filelock            pip                 tty
# _statistics         flake8              pipes               turtle
# _string             flask               pkce                turtledemo
# _strptime           fnmatch             pkg_resources       twisted
# _struct             fontTools           pkginfo             typeguard
# _symtable           fractions           pkgutil             types
# _system_path        frozendict          platform            typing
# _testbuffer         frozenlist          platformdirs        typing_extensions
# _testcapi           fsspec              plistlib            tzdata
# _testclinic         ftplib              plotly              uc_micro
# _testconsole        functools           pluggy              ujson
# _testimportmultiple gc                  ply                 unicodedata
# _testinternalcapi   genericpath         poplib              unicodedata2
# _testmultiphase     gensim              posixpath           unidecode
# _testsinglephase    getopt              pprint              unittest
# _thread             getpass             profile             urllib
# _threading_local    gettext             prometheus_client   urllib3
# _tkinter            git                 prompt_toolkit      uu
# _tokenize           gitdb               protego             uuid
# _tracemalloc        glob                pstats              venv
# _typing             graphlib            psutil              w3lib
# _uuid               greenlet            pty                 warnings
# _warnings           gzip                ptyprocess          watchdog
# _weakref            h11                 pure_eval           wave
# _weakrefset         h5py                py                  wcwidth
# _win32sysloader     hashlib             py_compile          weakref
# _winapi             heapdict            pyarrow             webbrowser
# _winxptheme         heapq               pyasn1              webencodings
# _wmi                hmac                pyasn1_modules      websocket
# _xxinterpchannels   holoviews           pyclbr              werkzeug
# _xxsubinterpreters  html                pycodestyle         whatthepatch
# _yaml               http                pycosat             wheel
# _zoneinfo           httpcore            pycparser           widgetsnbextension
# abc                 httpx               pyct                win2kras
# adodbapi            hvplot              pycurl              win32api
# aext_assistant      hyperlink           pydantic            win32clipboard
# aext_assistant_server idlelib             pydantic_core       win32com
# aext_core           idna                pydeck              win32con
# aext_core_server    imagecodecs         pydispatch          win32console
# aext_panels         imageio             pydoc               win32cred
# aext_panels_server  imagesize           pydoc_data          win32crypt
# aext_share_notebook imaplib             pydocstyle          win32cryptcon
# aext_share_notebook_server imblearn            pyexpat             win32ctypes
# aext_shared         imghdr              pyflakes            win32event
# aext_toolbox        importlib           pygments            win32evtlog
# afxres              importlib_metadata  pylab               win32evtlogutil
# aifc                importlib_resources pylint              win32file
# aiobotocore         incremental         pylint_venv         win32gui
# aiohappyeyeballs    inflect             pyls_spyder         win32gui_struct
# aiohttp             inflection          pylsp               win32help
# aioitertools        iniconfig           pylsp_black         win32inet
# aiosignal           inspect             pylsp_jsonrpc       win32inetcon
# alabaster           intake              pyodbc              win32job
# alembic             intervaltree        pyparsing           win32lz
# altair              io                  pytest              win32net
# anaconda_anon_usage ipaddress           pythoncom           win32netcon
# anaconda_catalogs   ipykernel           pythonjsonlogger    win32pdh
# anaconda_cloud_auth ipykernel_launcher  pytoolconfig        win32pdhquery
# anaconda_navigator  ipython_genutils    pytz                win32pdhutil
# anaconda_project    ipywidgets          pyviz_comms         win32pipe
# annotated_types     isapi               pywin               win32print
# antigravity         isort               pywin32_bootstrap   win32process
# anyio               isympy              pywin32_testutil    win32profile
# appdirs             itemadapter         pywintypes          win32ras
# archspec            itemloaders         pywt                win32rcparser
# argon2              itertools           qdarkstyle          win32security
# argparse            itsdangerous        qstylizer           win32service
# array               jedi                qtawesome           win32serviceutil
# arrow               jellyfish           qtconsole           win32timezone
# ast                 jinja2              qtpy                win32trace
# astroid             jmespath            queue               win32traceutil
# astropy             joblib              queuelib            win32transaction
# astropy_iers_data   json                quopri              win32ts
# asttokens           json5               random              win32ui
# async_lru           jsonpatch           rasutil             win32uiole
# asyncio             jsonpointer         re                  win32verstamp
# atexit              jsonschema          referencing         win32wnet
# atomicwrites        jsonschema_specifications regcheck            win_inet_pton
# attr                jupyter             regex               winerror
# attrs               jupyter_client      regutil             winioctlcon
# audioop             jupyter_console     repo_cli            winnt
# autocommand         jupyter_core        reprlib             winperf
# automat             jupyter_events      requests            winpty
# autopep8            jupyter_lsp         requests_file       winreg
# babel               jupyter_server      requests_toolbelt   winsound
# backports           jupyter_server_terminals rfc3339_validator   winxpgui
# base64              jupyterlab          rfc3986_validator   winxptheme
# bcrypt              jupyterlab_plotly   rich                wrapt
# bdb                 jupyterlab_pygments rlcompleter         wsgiref
# binaryornot         jupyterlab_server   rope                xarray
# binascii            jupyterlab_widgets  rpds                xdrlib
# binstar_client      jwt                 rtree               xlwings
# bisect              keyring             ruamel_yaml         xlwingsjs
# black               keyword             runpy               xml
# blackd              kiwisolver          s3fs                xmlrpc
# bleach              lazy_loader         sched               xxlimited
# blib2to3            lazy_object_proxy   scipy               xxlimited_35
# blinker             lckr_jupyterlab_variableinspector scrapy              xxsubtype
# bokeh               lib2to3             seaborn             xyzservices
# boltons             libarchive          secrets             yaml
# botocore            libmambapy          select              yapf
# bottleneck          lief                selectors           yapf_third_party
# brotli              linecache           semver              yapftests
# bs4                 linkify_it          send2trash          yarl
# builtins            llvmlite            sentry_sdk          zict
# bz2                 lmdb                service_identity    zipapp
# cProfile            locale              servicemanager      zipfile
# cachetools          locket              setuptools          zipimport
# calendar            logging             shelve              zipp
# certifi             lxml                shlex               zlib
# cffi                lz4                 shutil              zmq
# cgi                 lzma                signal              zoneinfo
# cgitb               mailbox             sipbuild            zope
# chardet             mailcap             site                zstandard
# charset_normalizer  mako                six
# chunk               markdown            skimage
# click               markdown_it         sklearn
#
# Enter any module name to get more help.  Or, type "modules spam" to search
# for modules whose name or summary contain the string "spam".
#
# ✅ You’re on a modern Python version!
